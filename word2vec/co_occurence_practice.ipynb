# %% [markdown]
# <a href="https://colab.research.google.com/github/docsportellochrys/nlp-learning/blob/main/word2vec/co_occurence_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import re

# %%
file_path = 'crying_49.txt'

# %%
with open(file_path, 'r', encoding='utf-8') as file:
  text = file.read()

# %%
text = text.lower()
text[500:1000]
# Out:
# ' in the living room, stared at by the greenish dead eye of the tv tube, spoke the name of god, tried to feel as drunk as possible. but this did not work. she thought of a hotel room in mazatlan whose door had just been slammed, it seemed forever, waking up two hundred birds down in the lobby; a sunrise over the library slope at cornell university that nobody out on it had seen because the slope faces west; a dry, disconsolate tune from the fourth movement of the bartok concerto for orchestra; a '

# %%
text = re.sub(r'[^a-z\s\.\?!]', '', text)
text[500:1000]
# Out:
# 'living room stared at by the greenish dead eye of the tv tube spoke the name of god tried to feel as drunk as possible. but this did not work. she thought of a hotel room in mazatlan whose door had just been slammed it seemed forever waking up two hundred birds down in the lobby a sunrise over the library slope at cornell university that nobody out on it had seen because the slope faces west a dry disconsolate tune from the fourth movement of the bartok concerto for orchestra a whitewashed bust '

# %%
sentences = re.split(r'[\.\?!]', text)
sentences[1:3]
# Out:
# [' oedipa stood in the living room stared at by the greenish dead eye of the tv tube spoke the name of god tried to feel as drunk as possible',
#  ' but this did not work']

# %%
sentences = [sentence.split() for sentence in sentences if sentence]
sentences[3]
# Out:
# ['she',
#  'thought',
#  'of',
#  'a',
#  'hotel',
#  'room',
#  'in',
#  'mazatlan',
#  'whose',
#  'door',
#  'had',
#  'just',
#  'been',
#  'slammed',
#  'it',
#  'seemed',
#  'forever',
#  'waking',
#  'up',
#  'two',
#  'hundred',
#  'birds',
#  'down',
#  'in',
#  'the',
#  'lobby',
#  'a',
#  'sunrise',
#  'over',
#  'the',
#  'library',
#  'slope',
#  'at',
#  'cornell',
#  'university',
#  'that',
#  'nobody',
#  'out',
#  'on',
#  'it',
#  'had',
#  'seen',
#  'because',
#  'the',
#  'slope',
#  'faces',
#  'west',
#  'a',
#  'dry',
#  'disconsolate',
#  'tune',
#  'from',
#  'the',
#  'fourth',
#  'movement',
#  'of',
#  'the',
#  'bartok',
#  'concerto',
#  'for',
#  'orchestra',
#  'a',
#  'whitewashed',
#  'bust',
#  'of',
#  'jay',
#  'gould',
#  'that',
#  'pierce',
#  'kept',
#  'over',
#  'the',
#  'bed',
#  'on',
#  'a',
#  'shelf',
#  'so',
#  'narrow',
#  'for',
#  'it',
#  'shed',
#  'always',
#  'had',
#  'the',
#  'hovering',
#  'fear',
#  'it',
#  'would',
#  'someday',
#  'topple',
#  'on',
#  'them']

# %%
co_occurrence = defaultdict(lambda: defaultdict(int))

# %%
def update_co_occurrence(sentence, window_size=1):
    words = ["<START>"] + sentence + ["<END>"]
    for i, word in enumerate(words):
        for j in range(max(0, i - window_size), min(len(words), i + window_size + 1)):
            if i != j:
                co_occurrence[word][words[j]] += 1

for sentence in sentences:
    update_co_occurrence(sentence)

co_occurrence['absurd']
# Out:
# defaultdict(int, {'is': 1, 'she': 1, 'to': 1, 'lengths': 1})

# %%
tokens = list(co_occurrence.keys())
tokens[:10]
# Out:
# ['<START>',
#  'thomas',
#  'pynchon',
#  'the',
#  'crying',
#  'of',
#  'lot',
#  'one',
#  'summer',
#  'afternoon']

# %%
co_occurrence_df = pd.DataFrame(co_occurrence).fillna(0).astype(int).reindex(tokens, columns=tokens, fill_value=0)
co_occurrence_df
# Out:
#             <START>  thomas  pynchon  the  crying   of  lot  one  summer  \
# <START>           0       1        0  199       0    6    0   18       0
# thomas            1       0        1    0       0    0    0    0       0
# pynchon           0       1        0    1       0    0    0    0       0
# the             199       0        1    0       2  256    9    8       0
# crying            0       0        0    2       0    2    0    1       0
# ...             ...     ...      ...  ...     ...  ...  ...  ...     ...
# belong            0       0        0    0       0    0    0    0       0
# priesthood        0       0        0    1       0    1    0    0       0
# remote            0       0        0    0       0    0    0    0       0
# cleared           0       0        0    0       0    0    0    0       0
# throat            0       0        0    0       0    0    0    0       0
#
#             afternoon  ...  relentless  napes  necks  snap  echoed  belong  \
# <START>             0  ...           0      0      0     0       0       0
# thomas              0  ...           0      0      0     0       0       0
# pynchon             0  ...           0      0      0     0       0       0
# the                 1  ...           0      1      0     0       0       0
# crying              0  ...           0      0      0     0       0       0
# ...               ...  ...         ...    ...    ...   ...     ...     ...
# belong              0  ...           0      0      0     0       0       0
# priesthood          0  ...           0      0      0     0       0       0
# remote              0  ...           0      0      0     0       0       0
# cleared             0  ...           0      0      0     0       0       0
# throat              0  ...           0      0      0     0       0       0
#
#             priesthood  remote  cleared  throat
# <START>              0       0        0       0
# thomas               0       0        0       0
# pynchon              0       0        0       0
# the                  1       0        0       0
# crying               0       0        0       0
# ...                ...     ...      ...     ...
# belong               0       0        0       0
# priesthood           0       0        0       0
# remote               0       0        0       0
# cleared              0       0        0       0
# throat               0       0        0       0
#
# [7681 rows x 7681 columns]
# Warning: Total number of columns (7681) exceeds max_columns (20) limiting to first (20) columns.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# co_occurrence_df['<START>'].plot(kind='hist', bins=20, title='<START>')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# co_occurrence_df['thomas'].plot(kind='hist', bins=20, title='thomas')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# co_occurrence_df['pynchon'].plot(kind='hist', bins=20, title='pynchon')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# co_occurrence_df['the'].plot(kind='hist', bins=20, title='the')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# co_occurrence_df.plot(kind='scatter', x='<START>', y='thomas', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# co_occurrence_df.plot(kind='scatter', x='thomas', y='pynchon', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# co_occurrence_df.plot(kind='scatter', x='pynchon', y='the', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# co_occurrence_df.plot(kind='scatter', x='the', y='crying', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['time']
#   ys = series['<START>']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = co_occurrence_df.sort_values('time', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('time')
# _ = plt.ylabel('<START>')
